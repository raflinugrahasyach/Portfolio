# %% [markdown]
# # Data Preparations

# %% [markdown]
# ## Understanding Data Structure

# %%
import pandas as pd

# import raw dataset
raw_df = pd.read_csv("employee_raw_dataset.csv")

raw_df.head()
# Out:
#    Employee_ID    Gender  Department Education_Level Job_Level  Age  \
# 0            1    female  Operations          Master    Junior   15
# 1            2   Female           Hr        Bachelor   Officer   70
# 2            3      MALE        Risk        Bachelor    Junior   32
# 3            4   Female           IT        Bachelor   Manager   27
# 4            5   Female      Finance        Bachelor    Junior   16
#
#    Years_Experience  Training_Hours  Monthly_Salary  Performance_Score  \
# 0                 7            25.6      10702825.0               99.5
# 1                12            10.2      15735781.0               76.6
# 2                18            33.2      -5000000.0               86.0
# 3                 2            13.8      21446446.0              120.0
# 4                14           104.1      10685352.0               73.2
#
#    Attendance_Rate  Project_Completed  Promotion_Last_3Y
# 0             98.0                  6                  1
# 1             85.5                  2                  0
# 2             91.6                  5                  0
# 3             85.7                  3                  0
# 4            130.0                  2                  1

# %%
import pandas as pd

# import raw dataset
raw_df = pd.read_csv("employee_raw_dataset.csv")

# move Employee_ID to first column
raw_df.insert(0, 'Employee_ID', raw_df.pop('Employee_ID'))

# excel-like freeze pane
display(
    raw_df.style
    .hide(axis="index")
    .set_table_styles([
        # freeze header
        {
            'selector': 'thead th',
            'props': [
                ('position', 'sticky'),
                ('top', '0'),
                ('background', "#424040"),
                ('z-index', '3')
            ]
        },

        # freeze Employee_ID column
        {
            'selector': 'thead th.col0',
            'props': [
                ('position', 'sticky'),
                ('left', '0'),
                ('z-index', '4')
            ]
        },

        {
            'selector': 'tbody td.col0',
            'props': [
                ('position', 'sticky'),
                ('left', '0'),
                ('background', "#424040"),
                ('z-index', '2')
            ]
        }
    ])
    .set_table_attributes(
        'style="display:block; overflow:auto; max-height:400px; white-space:nowrap; border-collapse:collapse;"'
    )
)
# Out:
# <style type="text/css">
# #T_c8aea thead th {
#   position: sticky;
#   top: 0;
#   background: #424040;
#   z-index: 3;
# }
# #T_c8aea thead th.col0 {
#   position: sticky;
#   left: 0;
#   z-index: 4;
# }
# #T_c8aea tbody td.col0 {
#   position: sticky;
#   left: 0;
#   background: #424040;
#   z-index: 2;
# }
# </style>
# <table id="T_c8aea" style="display:block; overflow:auto; max-height:400px; white-space:nowrap; border-collapse:collapse;">
#   <thead>
#     <tr>
#       <th id="T_c8aea_level0_col0" class="col_heading level0 col0" >Employee_ID</th>
#       <th id="T_c8aea_level0_col1" class="col_heading level0 col1" >Gender</th>
#       <th id="T_c8aea_level0_col2" class="col_heading level0 col2" >Department</th>
#       <th id="T_c8aea_level0_col3" class="col_heading level0 col3" >Education_Level</th>
#       <th id="T_c8aea_level0_col4" class="col_heading level0 col4" >Job_Level</th>
#       <th id="T_c8aea_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_c8aea_level0_col6" class="col_heading level0 col6" >Years_Experience</th>
#       <th id="T_c8aea_level0_col7" class="col_heading level0 col7" >Training_Hours</th>
#       <th id="T_c8aea_level0_col8" class="col_heading level0 col8" >Monthly_Salary</th>
#       <th id="T_c8aea_level0_col9" class="col_heading level0 col9" >Performance_Score</th>
#       <th id="T_c8aea_level0_col10" class="col_heading level0 col10" >Attendance_Rate</th>
#       <th id="T_c8aea_level0_col11" class="col_heading level0 col11" >Project_Completed</th>
#       <th id="T_c8aea_level0_col12" class="col_heading level0 col12" >Promotion_Last_3Y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c8aea_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c8aea_row0_col1" class="data row0 col1" >female</td>
#       <td id="T_c8aea_row0_col2" class="data row0 col2" >Operations</td>
#       <td id="T_c8aea_row0_col3" class="data row0 col3" >Master</td>
#       <td id="T_c8aea_row0_col4" class="data row0 col4" >Junior</td>
#       <td id="T_c8aea_row0_col5" class="data row0 col5" >15</td>
#       <td id="T_c8aea_row0_col6" class="data row0 col6" >7</td>
#       <td id="T_c8aea_row0_col7" class="data row0 col7" >25.600000</td>
#       <td id="T_c8aea_row0_col8" class="data row0 col8" >10702825.000000</td>
#       <td id="T_c8aea_row0_col9" class="data row0 col9" >99.500000</td>
#       <td id="T_c8aea_row0_col10" class="data row0 col10" >98.000000</td>
#       <td id="T_c8aea_row0_col11" class="data row0 col11" >6</td>
#       <td id="T_c8aea_row0_col12" class="data row0 col12" >1</td>
#     </tr>
#     <tr>
#       <td id="T_c8aea_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_c8aea_row1_col1" class="data row1 col1" > Female </td>
#       <td id="T_c8aea_row1_col2" class="data row1 col2" >Hr</td>
#       <td id="T_c8aea_row1_col3" class="data row1 col3" >Bachelor</td>
#       <td id="T_c8aea_row1_col4" class="data row1 col4" >Officer</td>
#       <td id="T_c8aea_row1_col5" class="data row1 col5" >70</td>
#       <td id="T_c8aea_row1_col6" class="data row1 col6" >12</td>
#       <td id="T_c8aea_row1_col7" class="data row1 col7" >10.200000</td>
#       <td id="T_c8aea_row1_col8" class="data row1 col8" >15735781.000000</td>
#       <td id="T_c8aea_row1_col9" class="data row1 col9" >76.600000</td>
#       <td id="T_c8aea_row1_col10" class="data row1 col10" >85.500000</td>
#       <td id="T_c8aea_row1_col11" class="data row1 col11" >2</td>
#       <td id="T_c8aea_row1_col12" class="data row1 col12" >0</td>
#     </tr>
#     <tr>
#       <td id="T_c8aea_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_c8aea_row2_col1" class="data row2 col1" >MALE</td>
#       <td id="T_c8aea_row2_col2" class="data row2 col2" >Risk</td>
#       <td id="T_c8aea_row2_col3" class="data row2 col3" >Bachelor</td>
#       <td id="T_c8aea_row2_col4" class="data row2 col4" >Junior</td>
#       <td id="T_c8aea_row2_col5" class="data row2 col5" >32</td>
#       <td id="T_c8aea_row2_col6" class="data row2 col6" >18</td>
#       <td id="T_c8aea_row2_col7" class="data row2 col7" >33.200000</td>
#       <td id="T_c8aea_row2_col8" class="data row2 col8" >-5000000.000000</td>
#       <td id="T_c8aea_row2_col9" class="data row2 col9" >86.000000</td>
#       <td id="T_c8aea_row2_col10" class="data row2 col10" >91.600000</td>
#       <td id="T_c8aea_row2_col11" class="data row2 col11" >5</td>
#       <td id="T_c8aea_row2_col12" class="data row2 col12" >0</td>
#     </tr>
#     <tr>
#       <td id="T_c8aea_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_c8aea_row3_col1" class="data row3 col1" > Female </td>
#       <td id="T_c8aea_row3_col2" class="data row3 col2" >IT</td>
#       <td id="T_c8aea_row3_col3" class="data row3 col3" >Bachelor</td>
#       <td id="T_c8aea_row3_col4" class="data row3 col4" >Manager</td>
#       <td id="T_c8aea_row3_col5" class="data row3 col5" >27</td>
#       <td id="T_c8aea_row3_col6" class="data row3 col6" >2</td>
#       <td id="T_c8aea_row3_col7" class="data row3 col7" >13.800000</td>
#       <td id="T_c8aea_row3_col8" class="data row3 col8" >21446446.000000</td>
#       <td id="T_c8aea_row3_col9" class="data row3 col9" >120.000000</td>
#       <td id="T_c8aea_row3_col10" class="data row3 col10" >85.700000</td>
#       <td id="T_c8aea_row3_col11" class="data row3 col11" >3</td>
#       <td id="T_c8aea_row3_col12" class="data row3 col12" >0</td>
#     </tr>
#     <tr>
#       <td id="T_c8aea_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_c8aea_row4_col1" class="data row4 col1" > Female </td>
#       <td id="T_c8aea_row4_col2" class="data row4 col2" >Finance</td>
#       <td id="T_c8aea_row4_col3" class="data row4 col3" >Bachelor</td>
#       <td id="T_c8aea_row4_col4" class="data row4 col4" >Junior</td>
#       <td id="T_c8aea_row4_col5" class="data row4 col5" >16</td>
#       <td id="T_c8aea_row4_col6" class="data row4 col6" >14</td>
#       <td id="T_c8aea_row4_col7" class="data row4 col7" >104.100000</td>
#       <td id="T_c8aea_row4_col8" class="data row4 col8" >10685352.000000</td>
#       <td id="T_c8aea_row4_col9" class="data row4 col9" >73.200000</td>
#       <td id="T_c8aea_row4_col10" class="data row4 col10" >130.000000</td>
#       <td id="T_c8aea_row4_col11" class="data row4 col11" >2</td>
#       <td id="T_c8aea_row4_col12" class="data row4 col12" >1</td>
#     </tr>
#     <tr>
#       <td id="T_c8aea_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_c8aea_row5_col1" class="data row5 col1" >Female</td>
#       <td id="T_c8aea_row5_col2" class="data row5 col2" >Operations</td>
#       <td id="T_c8aea_row5_col3" class="data row5 col3" >PhD</td>
#       <td id="T_c8aea_row5_col4" class="data row5 col4" >Senior Manager</td>
#       <td id="T_c8aea_row5_col5" class="data row5 col5" >41</td>
#       <td id="T_c8aea_row5_col6" class="data row5 col6" >9</td>
#       <td id="T_c8aea_row5_col7" class="data row5 col7" >16.000000</td>
#       <td id="T_c8aea_row5_col8" class="data row5 col8" >4095998.000000</td>
#       <td id="T_c8aea_row5_col9" class="data row5 col9" >83.100000</td>
#       <td id="T_c8aea_row5_col10" class="data row5 col10" >90.900000</td>
#       <td id="T_c8aea_row5_col11" class="data row5 col11" >5</td>
#       <td id="T_c8aea_row5_col12" class="data row5 col12" >1</td>
#     </tr>
#     <tr>
#       <td id="T_c8aea_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_c8aea_row6_col1" class="data row6 col1" >MALE</td>
#       <td id="T_c8aea_row6_col2" class="data row6 col2" >Hr</td>
#       <td id="T_c8aea_row6_col3" class="data row6 col3" >Bachelor</td>
#       <td id="T_c8aea_row6_col4" class="data row6 col4" >Officer</td>
#       <td id="T_c8aea_row6_col5" class="data row6 col5" >29</td>
#       <td id="T_c8aea_row6_col6" class="data row6 col6" >8</td>
#       <td id="T_c8aea_row6_col7" class="data row6 col7" >16.700000</td>
#       <td id="T_c8aea_row6_col8" class="data row6 col8" >6268244.000000</td>
#       <td id="T_c8aea_row6_col9" class="data row6 col9" >79.200000</td>
#       <td id="T_c8aea_row6_col10" class="data row6 col10" >92.800000</td>
#       <td id="T_c8aea_row6_col11" class="data row6 col11" >5</td>
#       <td id="T_c8aea_row6_col12" class="data row6

# %%
raw_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        510 non-null    int64
#  1   Gender             510 non-null    str
#  2   Department         495 non-null    str
#  3   Education_Level    510 non-null    str
#  4   Job_Level          510 non-null    str
#  5   Age                510 non-null    int64
#  6   Years_Experience   510 non-null    int64
#  7   Training_Hours     475 non-null    float64
#  8   Monthly_Salary     485 non-null    float64
#  9   Performance_Score  510 non-null    float64
#  10  Attendance_Rate    510 non-null    float64
#  11  Project_Completed  510 non-null    int64
#  12  Promotion_Last_3Y  510 non-null    int64
# dtypes: float64(4), int64(5), str(4)
# memory usage: 65.0 KB

# %%
raw_df.describe()
# Out:
#        Employee_ID         Age  Years_Experience  Training_Hours  \
# count   510.000000  510.000000        510.000000      475.000000
# mean    245.647059   33.731373          8.049020       20.910737
# std     147.121673    8.871291          4.944838       15.828396
# min       1.000000   11.000000         -6.000000        0.200000
# 25%     118.250000   28.000000          5.000000        9.700000
# 50%     245.500000   33.000000          8.000000       17.100000
# 75%     372.750000   40.000000         11.000000       27.900000
# max     500.000000   70.000000         22.000000      104.100000
#
#        Monthly_Salary  Performance_Score  Attendance_Rate  Project_Completed  \
# count    4.850000e+02         510.000000       510.000000         510.000000
# mean     1.249223e+07          77.737843        92.944118           5.072549
# std      5.094032e+06          11.968562         5.605694           2.302436
# min     -5.000000e+06          39.600000        77.800000           0.000000
# 25%      9.554922e+06          70.900000        89.525000           4.000000
# 50%      1.206146e+07          77.300000        92.900000           5.000000
# 75%      1.525419e+07          84.500000        96.000000           6.000000
# max      4.464827e+07         120.000000       130.000000          13.000000
#
#        Promotion_Last_3Y
# count         510.000000
# mean            0.239216
# std             0.427024
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max             1.000000

# %% [markdown]
# **Your Task:** Create a function describe some basic statistics as similar to the "describe(include="int64")' function. But you have to add more important metrics to your functions, such as variance, mode, Skewness, Kurtosis, number of missing value (percentage of missing values), nomal distribution or not, number of outlier values.

# %%
raw_df.describe(include="string")
# Out:
#         Gender Department Education_Level Job_Level
# count      510        495             510       510
# unique       9         13               8         5
# top     female  Marketing        Bachelor   Officer
# freq       113         64             263       160

# %% [markdown]
# **Your Task:** Create a function describe some basic statistics as similar to the "describe(include="string")' function. But you have to add more important metrics to your functions, mode, number of missing value (percentage of missing values).

# %% [markdown]
# ## Handling Missing Value
#
# Before handling missing values, an initial inspection was conducted to identify categorical features containing incomplete data. This step aims to measure the number and percentage of missing values in each categorical variable, helping determine the appropriate data cleaning strategy before further analysis or modeling.

# %%
raw_df.isnull().sum()
# Out:
# Employee_ID           0
# Gender                0
# Department           15
# Education_Level       0
# Job_Level             0
# Age                   0
# Years_Experience      0
# Training_Hours       35
# Monthly_Salary       25
# Performance_Score     0
# Attendance_Rate       0
# Project_Completed     0
# Promotion_Last_3Y     0
# dtype: int64

# %%
missing_percent = raw_df.isnull().mean() * 100
missing_percent.sort_values(ascending=False)
# Out:
# Training_Hours       6.862745
# Monthly_Salary       4.901961
# Department           2.941176
# Employee_ID          0.000000
# Gender               0.000000
# Education_Level      0.000000
# Job_Level            0.000000
# Age                  0.000000
# Years_Experience     0.000000
# Performance_Score    0.000000
# Attendance_Rate      0.000000
# Project_Completed    0.000000
# Promotion_Last_3Y    0.000000
# dtype: float64

# %%
import pandas as pd

# detect missing values (all columns)
missing_count = raw_df.isnull().sum()

# create table
missing_table = pd.DataFrame({
    'Feature': missing_count.index,
    'Missing Value': missing_count.values,
    'Missing Percentage (%)': (missing_count.values / len(df)) * 100
})

# sort
missing_table = missing_table.sort_values(
    by='Missing Value',
    ascending=False
)

# display
missing_table
# Out:
#               Feature  Missing Value  Missing Percentage (%)
# 0         Employee_ID              0                     0.0
# 1              Gender              0                     0.0
# 2          Department              0                     0.0
# 3     Education_Level              0                     0.0
# 4           Job_Level              0                     0.0
# 5                 Age              0                     0.0
# 6    Years_Experience              0                     0.0
# 7      Training_Hours              0                     0.0
# 8      Monthly_Salary              0                     0.0
# 9   Performance_Score              0                     0.0
# 10    Attendance_Rate              0                     0.0
# 11  Project_Completed              0                     0.0
# 12  Promotion_Last_3Y              0                     0.0

# %% [markdown]
# ### Numeric Values

# %%
raw_df["Monthly_Salary"] = raw_df["Monthly_Salary"].fillna(raw_df["Monthly_Salary"].median())
raw_df["Training_Hours"] = raw_df["Training_Hours"].fillna(raw_df["Training_Hours"].median())

# %% [markdown]
# ### Categoric Values

# %%
raw_df["Department"] = raw_df["Department"].fillna(raw_df["Department"].mode()[0])
raw_df["Education_Level"] = raw_df["Education_Level"].fillna(raw_df["Education_Level"].mode()[0])

# %%
import pandas as pd

for col in raw_df.columns:
    if raw_df[col].dtype in ["int64", "float64"]:
        raw_df[col] = raw_df[col].fillna(raw_df[col].median())
    else:
        raw_df[col] = raw_df[col].fillna(raw_df[col].mode()[0])

# %% [markdown]
# ## Remove Duplicate Data

# %%
raw_df.duplicated().sum()
# Out:
# np.int64(10)

# %%
raw_df = raw_df.drop_duplicates()

# %% [markdown]
# ## Inconsisten Categorical Values

# %%
raw_df["Gender"].unique()
# Out:
# <ArrowStringArray>
# ['female', ' Female ', 'MALE', 'Female', 'Male', 'M', 'Unknown', 'F', '-']
# Length: 9, dtype: str

# %%
raw_df["Gender"] = raw_df["Gender"].astype(str).str.strip().str.lower().replace({
    "female":"Female","f":"Female","male":"Male","m":"Male","-":"Unknown"
}).fillna("Unknown")

# %%
raw_df["Department"].unique()
# Out:
# <ArrowStringArray>
# ['Operations',         'Hr',       'Risk',         'IT',    'Finance',
#  'Compliance',  'Marketing',      'XDept',         'HR',    'finance',
#     'Unknown',        '999',        '???']
# Length: 13, dtype: str

# %%
raw_df["Department"] = (
    raw_df["Department"].astype(str).str.strip().str.lower().replace({
        "hr":"HR","operations":"Operations","risk":"Risk","it":"IT",
        "finance":"Finance","compliance":"Compliance","marketing":"Marketing",
        "xdept":"Unknown","999":"Unknown","???":"Unknown","nan":"Unknown"
    }).fillna("Unknown")
)

# %%
raw_df["Education_Level"].unique()
# Out:
# <ArrowStringArray>
# [         'Master',        'Bachelor',             'PhD',              'S1',
#          'Diploma',               '?',        'Magister', 'Bachelor Degree']
# Length: 8, dtype: str

# %%
raw_df["Education_Level"] = (
    raw_df["Education_Level"].astype(str).str.strip().str.lower().replace({
        "phd":"PhD",
        "master":"Master","magister":"Master",
        "bachelor":"Bachelor","s1":"Bachelor","bachelor degree":"Bachelor",
        "diploma":"Diploma",
        "?":"Unknown","nan":"Unknown"
    }).fillna("Unknown")
)

# %%
raw_df["Job_Level"].unique()
# Out:
# <ArrowStringArray>
# ['Junior', 'Officer', 'Manager', 'Senior Manager', 'Supervisor']
# Length: 5, dtype: str

# %%
raw_df["Job_Level_Encoded"] = raw_df["Job_Level"].map({
    "Junior":1,
    "Officer":2,
    "Supervisor":3,
    "Manager":4,
    "Senior Manager":5
})

# %%
def clean(col, mapping):
    if col in raw_df:
        raw_df[col] = (
            raw_df[col].astype(str).str.strip().str.lower()
            .map(mapping).fillna("Unknown")
        )

# Gender
clean("Gender", {"female":"Female","f":"Female","male":"Male","m":"Male"})

# Department
clean("Department", {
    "hr":"HR","operations":"Operations","risk":"Risk","it":"IT",
    "finance":"Finance","compliance":"Compliance","marketing":"Marketing"
})

# Education
clean("Education_Level", {
    "phd":"PhD","master":"Master","magister":"Master",
    "bachelor":"Bachelor","s1":"Bachelor","bachelor degree":"Bachelor",
    "diploma":"Diploma"
})

# Job Level + Encoding
clean("Job_Level", {
    "junior":"Junior","officer":"Officer","supervisor":"Supervisor",
    "manager":"Manager","senior manager":"Senior Manager"
})

if "Job_Level" in raw_df:
    raw_df["Job_Level_Encoded"] = raw_df["Job_Level"].map({
        "Junior":1,"Officer":2,"Supervisor":3,"Manager":4,"Senior Manager":5
    })

# %% [markdown]
# ## Outlier Detection

# %%
Q1 = raw_df["Monthly_Salary"].quantile(0.25)
Q3 = df["Monthly_Salary"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_salary = df[
    (df["Monthly_Salary"] < lower_bound) |
    (df["Monthly_Salary"] > upper_bound)
]

outliers_salary
# Out:
#      Employee_ID    Gender  Department Education_Level   Job_Level  Age  \
# 2              3      MALE        Risk        Bachelor      Junior   32
# 66            67    Female          Hr        Bachelor     Officer   46
# 139          140   Female    Marketing          Master     Manager   25
# 206          207   Female   Compliance        Bachelor     Manager   27
# 230          231    Female     Finance        Bachelor  Supervisor   27
# 243          244      MALE     finance        Bachelor     Officer   29
# 346          347      MALE   Marketing          Master  Supervisor   53
# 365          366   Female         Risk          Master     Manager   28
# 478          479   Female    Marketing         Diploma     Manager   47
# 502            3      MALE        Risk        Bachelor      Junior   32
# 507            3      MALE        Risk        Bachelor      Junior   32
#
#      Years_Experience  Training_Hours  Monthly_Salary  Performance_Score  \
# 2                  18            33.2      -5000000.0               86.0
# 66                 -4            17.1       1403602.0               83.0
# 139                 8             1.9      23956065.0               46.4
# 206                10             3.1      38133417.0               47.9
# 230                 7            14.3      31180707.0               39.6
# 243                 3            49.6      41352372.0               57.6
# 346                11            15.4      24293154.0               54.5
# 365                13            12.3      36497484.0               48.7
# 478                13            34.6      44648274.0               48.0
# 502                18            33.2      -5000000.0               86.0
# 507                18            33.2      -5000000.0               86.0
#
#      Attendance_Rate  Project_Completed  Promotion_Last_3Y
# 2               91.6                  5                  0
# 66              98.5                  4                  1
# 139             81.9                  3                  0
# 206             89.6                  6                  0
# 230             96.1                  2                  0
# 243             96.0                  6                  0
# 346             99.3                  4                  0
# 365             93.6                  5                  1
# 478             91.1                  7                  0
# 502             91.6                  5                  0
# 507             91.6                  5                  0

# %% [markdown]
# **Your Task:**
#
# - Create a function to detect all outlier values at your dataset, esspecially to numerical variables.
# - Create a function to replace all outlier values at your dataset, esspecially to numerical variables.

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### Grupping Numerical Values

# %%
def age_group(age):
    if age < 30:
        return "Young"
    elif age < 40:
        return "Mid Career"
    elif age < 50:
        return "Senior"
    else:
        return "Late Career"

raw_df["Age_Group"] = raw_df["Age"].apply(age_group)

# %%
def salary_band(s):
    if pd.isna(s):
        return "Unknown"
    if s < 8_000_000:
        return "Low Salary"
    elif s < 15_000_000:
        return "Middle Salary"
    elif s < 25_000_000:
        return "High Salary"
    else:
        return "Very High Salary"

raw_df["Salary_Band"] = raw_df["Monthly_Salary"].apply(salary_band)

# %%
def performance_category(score):
    if score >= 85:
        return "High Performer"
    elif score >= 70:
        return "Moderate Performer"
    else:
        return "Low Performer"

raw_df["Performance_Category"] = raw_df["Performance_Score"].apply(performance_category)

# %%
def attendance_category(rate):
    if rate >= 95:
        return "Excellent Attendance"
    elif rate >= 90:
        return "Good Attendance"
    elif rate >= 80:
        return "Warning Attendance"
    else:
        return "Poor Attendance"

df["Attendance_Category"] = df["Attendance_Rate"].apply(attendance_category)

# %% [markdown]
# **Your Task:**  Create a Python function that performs grouping (binning) of numerical variables into categories based on specified value ranges.

# %% [markdown]
# ### Encoding Categorical Variable

# %%
raw_df["Gender_Code"] = raw_df["Gender"].map({
    "Female": 0,
    "Male": 1
})

# %%
job_level_order = {
    "Junior": 1,
    "Officer": 2,
    "Supervisor": 3,
    "Manager": 4,
    "Senior Manager": 5
}

raw_df["Job_Level_Code"] = raw_df["Job_Level"].map(job_level_order)

# %% [markdown]
# **Your Task:** Create a Python function that performs encoding of categorical variables by converting them into numerical representations suitable for machine learning models.

# %% [markdown]
# ### Standardization Z-Score

# %%
from scipy import stats

raw_df["Salary_ZScore"] = stats.zscore(raw_df["Monthly_Salary"])
raw_df["Performance_ZScore"] = stats.zscore(raw_df["Performance_Score"])
raw_df["Training_ZScore"] = stats.zscore(raw_df["Training_Hours"])

# %%
from scipy import stats

cols = ["Monthly_Salary", "Performance_Score", "Training_Hours"]

for c in cols:
    if c in raw_df.columns:
        raw_df[c + "_ZScore"] = stats.zscore(raw_df[c])

# %% [markdown]
# ### Min-Max Normalization

# %%
def minmax(col):
    return (raw_df[col] - raw_df[col].min()) / (raw_df[col].max() - raw_df[col].min())

raw_df["Salary_Normalized"] = minmax("Monthly_Salary")

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# ## Categorical Data

# %% [markdown]
# ### Frequency

# %%
raw_df["Department"].value_counts()
# Out:
# Department
# Finance       111
# HR             94
# Marketing      79
# Risk           59
# IT             53
# Operations     49
# Compliance     43
# Unknown        12
# Name: count, dtype: int64

# %% [markdown]
# ### Proportion

# %%
raw_df["Department"].value_counts(normalize=True) * 100
# Out:
# Department
# Marketing     12.929293
# Risk          12.323232
# Finance       11.919192
# IT            11.111111
# Hr            10.909091
# finance       10.909091
# Operations    10.303030
# Compliance     8.686869
# HR             8.484848
# XDept          0.606061
# Unknown        0.606061
# 999            0.606061
# ???            0.606061
# Name: proportion, dtype: float64

# %% [markdown]
# ### Contingency Table

# %%
pd.crosstab(raw_df["Department"], raw_df["Performance_Category"])
# Out:
# Performance_Category  High Performer  Low Performer  Moderate Performer
# Department
# Compliance                        14             11                  18
# Finance                           32             26                  53
# HR                                16             23                  55
# IT                                13             12                  28
# Marketing                         15             21                  43
# Operations                        10             13                  26
# Risk                              15             11                  33
# Unknown                            3              3                   6

# %%
pd.crosstab(
    raw_df["Department"],
    raw_df["Performance_Category"],
    normalize="index"
) * 100
# Out:
# Performance_Category  High Performer  Low Performer  Moderate Performer
# Department
# Compliance                 32.558140      25.581395           41.860465
# Finance                    28.828829      23.423423           47.747748
# HR                         17.021277      24.468085           58.510638
# IT                         24.528302      22.641509           52.830189
# Marketing                  18.987342      26.582278           54.430380
# Operations                 20.408163      26.530612           53.061224
# Risk                       25.423729      18.644068           55.932203
# Unknown                    25.000000      25.000000           50.000000

# %% [markdown]
# ## Numerical Data

# %% [markdown]
# ### Mean

# %%
raw_df["Monthly_Salary"].mean()
# Out:
# np.float64(12551309.162)

# %% [markdown]
# ### Median

# %%
raw_df["Monthly_Salary"].median()
# Out:
# np.float64(12061459.0)

# %% [markdown]
# ### Mode

# %%
raw_df["Monthly_Salary"].mode()
# Out:
# 0    12061459.0
# Name: Monthly_Salary, dtype: float64

# %% [markdown]
# ### Range

# %%
salary_range = raw_df["Monthly_Salary"].max() - raw_df["Monthly_Salary"].min()
salary_range
# Out:
# np.float64(40648274.0)

# %% [markdown]
# ### Standard Deviation

# %%
raw_df["Monthly_Salary"].std()
# Out:
# np.float64(4752530.249012)

# %% [markdown]
# ## Shape of Distribution

# %% [markdown]
# ### Skewness

# %%
raw_df["Monthly_Salary"].skew()
# Out:
# np.float64(1.7685645123268738)

# %% [markdown]
# ### Kurtosis

# %%
raw_df["Monthly_Salary"].kurt()
# Out:
# np.float64(8.856294414485015)

# %% [markdown]
# ## Relative Position

# %% [markdown]
# ### Percentiles

# %%
raw_df["Monthly_Salary"].quantile([0.10, 0.25, 0.50, 0.75, 0.90, 0.95])
# Out:
# 0.10     7172953.40
# 0.25     9717117.75
# 0.50    12061459.00
# 0.75    15060496.00
# 0.90    17737155.20
# 0.95    19140216.05
# Name: Monthly_Salary, dtype: float64

# %% [markdown]
# ### Quartiles

# %%
Q1 = df["Monthly_Salary"].quantile(0.25)
Q2 = df["Monthly_Salary"].quantile(0.50)
Q3 = df["Monthly_Salary"].quantile(0.75)

Q1, Q2, Q3
# Out:
# (np.float64(9554922.0), np.float64(12061459.0), np.float64(15254192.0))

# %% [markdown]
# ### Z-Score

# %%
raw_df[["Monthly_Salary", "Salary_ZScore"]].head()
# Out:
#    Monthly_Salary  Salary_ZScore
# 0      10702825.0      -0.389337
# 1      15735781.0       0.670729
# 2       4000000.0      -1.801119
# 3      21446446.0       1.873538
# 4      10685352.0      -0.393017

# %%
raw_df[raw_df["Salary_ZScore"].abs() > 2]
# Out:
#      Employee_ID  Gender  Department Education_Level   Job_Level  Age  \
# 63            64  Female          IT          Master     Officer   43
# 139          140  Female   Marketing          Master     Manager   25
# 206          207  Female  Compliance        Bachelor     Manager   27
# 230          231  Female     Finance        Bachelor  Supervisor   27
# 243          244    Male     Finance        Bachelor     Officer   29
# 303          304  Female     Finance        Bachelor      Junior   46
# 331          332  Female        Risk        Bachelor     Officer   26
# 333          334  Female  Operations        Bachelor  Supervisor   33
# 346          347    Male   Marketing          Master  Supervisor   53
# 365          366  Female        Risk          Master     Manager   28
# 478          479  Female   Marketing         Diploma     Manager   47
#
#      Years_Experience  Training_Hours  Monthly_Salary  Performance_Score  ...  \
# 63                  7             4.7      23002892.0               71.6  ...
# 139                 8             1.9      23956065.0               46.4  ...
# 206                10             3.1      38133417.0               47.9  ...
# 230                 7            14.3      31180707.0               39.6  ...
# 243                 3            49.6      41352372.0               57.6  ...
# 303                 0            10.7      23542938.0               48.7  ...
# 331                17            12.1      22592576.0               81.7  ...
# 333                14             3.5      23536929.0               54.4  ...
# 346                11            15.4      24293154.0               54.5  ...
# 365                13            12.3      36497484.0               48.7  ...
# 478                13            34.6      44648274.0               48.0  ...
#
#      Gender_Code  Job_Level_Code  Monthly_Salary_ZScore  \
# 63           0.0               2               2.201364
# 139          0.0               4               2.402126
# 206          0.0               4               5.388230
# 230          0.0               3               3.923816
# 243          1.0               2               6.066223
# 303          0.0               1               2.315111
# 331          0.0               2               2.114941
# 333          0.0               3               2.313846
# 346          1.0               3               2.473126
# 365          0.0               4               5.043662
# 478          0.0               4               6.760422
#
#      Performance_Score_ZScore Training_Hours_ZScore Salary_ZScore  \
# 63                  -0.506141             -1.079732      2.201364
# 139                 -2.733345             -1.273349      2.402126
# 206                 -2.600774             -1.190371      5.388230
# 230                 -3.334337             -0.415903      3.923816
# 243                 -1.743477              2.025053      6.066223
# 303                 -2.530069             -0.664839      2.315111
# 331                  0.386508             -0.568031      2.114941
# 333                 -2.026296             -1.162711      2.313846
# 346                 -2.017458             -0.339839      2.473126
# 365                 -2.530069             -0.554201      5.043662
# 478                 -2.591936              0.987820      6.760422
#
#     Performance_ZScore  Training_ZScore  Salary_Normalized  Employee_Index
# 63           -0.506141        -1.079732           0.467496        0.476610
# 139          -2.733345        -1.273349           0.490945       -0.797876
# 206          -2.600774        -1.190371           0.839726       -0.258702
# 230          -3.334337        -0.415903           0.668680       -0.945511
# 243          -1.743477         2.025053           0.918917        0.900873
# 303          -2.530069        -0.664839           0.480781       -0.534237
# 331           0.386508        -0.568031           0.457401        1.247196
# 333          -2.026296        -1.162711           0.480634       -0.459796
# 346          -2.017458        -0.339839           0.499238       -0.093343
# 365          -2.530069        -0.554201           0.799480       -0.213378
# 478          -2.591936         0.987820           1.000000        0.442381
#
# [11 rows x 27 columns]

# %% [markdown]
# ### T-Score

# %%
raw_df["Salary_TScore"] = 50 + (10 * raw_df["Salary_ZScore"])
raw_df[["Monthly_Salary", "Salary_ZScore", "Salary_TScore"]].head()
# Out:
#    Monthly_Salary  Salary_ZScore  Salary_TScore
# 0      10702825.0      -0.389337      46.106631
# 1      15735781.0       0.670729      56.707293
# 2       4000000.0      -1.801119      31.988808
# 3      21446446.0       1.873538      68.735379
# 4      10685352.0      -0.393017      46.069828

# %% [markdown]
# ## Association Metrics

# %% [markdown]
# ### Pearson Correlation

# %%
raw_df[[
    "Age",
    "Years_Experience",
    "Training_Hours",
    "Monthly_Salary",
    "Performance_Score",
    "Attendance_Rate",
    "Project_Completed"
]].corr(method="pearson")
# Out:
#                         Age  Years_Experience  Training_Hours  Monthly_Salary  \
# Age                1.000000         -0.009175        0.049182        0.000366
# Years_Experience  -0.009175          1.000000        0.050276       -0.009577
# Training_Hours     0.049182          0.050276        1.000000       -0.027328
# Monthly_Salary     0.000366         -0.009577       -0.027328        1.000000
# Performance_Score -0.017870          0.025440        0.003578       -0.194007
# Attendance_Rate    0.007820          0.015526        0.015251        0.048393
# Project_Completed  0.034889         -0.045257        0.011538       -0.061543
#
#                    Performance_Score  Attendance_Rate  Project_Completed
# Age                        -0.017870         0.007820           0.034889
# Years_Experience            0.025440         0.015526          -0.045257
# Training_Hours              0.003578         0.015251           0.011538
# Monthly_Salary             -0.194007         0.048393          -0.061543
# Performance_Score           1.000000        -0.024615          -0.009035
# Attendance_Rate            -0.024615         1.000000           0.001005
# Project_Completed          -0.009035         0.001005           1.000000

# %% [markdown]
# ### Spearman Rank Correlation

# %%
raw_df[[
    "Age",
    "Years_Experience",
    "Training_Hours",
    "Monthly_Salary",
    "Performance_Score",
    "Attendance_Rate",
    "Project_Completed"
]].corr(method="spearman")
# Out:
#                         Age  Years_Experience  Training_Hours  Monthly_Salary  \
# Age                1.000000         -0.011574        0.072245        0.000965
# Years_Experience  -0.011574          1.000000        0.059592       -0.031083
# Training_Hours     0.072245          0.059592        1.000000       -0.038407
# Monthly_Salary     0.000965         -0.031083       -0.038407        1.000000
# Performance_Score -0.027537          0.033197       -0.022624       -0.066733
# Attendance_Rate    0.004918          0.008499       -0.020564        0.050534
# Project_Completed  0.043089         -0.055489       -0.009488       -0.089653
#
#                    Performance_Score  Attendance_Rate  Project_Completed
# Age                        -0.027537         0.004918           0.043089
# Years_Experience            0.033197         0.008499          -0.055489
# Training_Hours             -0.022624        -0.020564          -0.009488
# Monthly_Salary             -0.066733         0.050534          -0.089653
# Performance_Score           1.000000        -0.037783          -0.024225
# Attendance_Rate            -0.037783         1.000000           0.018844
# Project_Completed          -0.024225         0.018844           1.000000

# %% [markdown]
# ### Point-Biserial Correlation

# %%
from scipy.stats import pointbiserialr

pointbiserialr(
    raw_df["Promotion_Last_3Y"],
    raw_df["Monthly_Salary"]
)
# Out:
# SignificanceResult(statistic=np.float64(-0.0314933363244098), pvalue=np.float64(0.482290008646971))

# %% [markdown]
# ### Covariance

# %%
raw_df[[
    "Age",
    "Years_Experience",
    "Training_Hours",
    "Monthly_Salary",
    "Performance_Score",
    "Attendance_Rate",
    "Project_Completed"
]].cov()
# Out:
#                             Age  Years_Experience  Training_Hours  \
# Age                   67.068232         -0.353908    5.830622e+00
# Years_Experience      -0.353908         22.182365    3.427796e+00
# Training_Hours         5.830622          3.427796    2.095554e+02
# Monthly_Salary     14257.871719    -214378.024248   -1.880102e+06
# Performance_Score     -1.657549          1.357034    5.866220e-01
# Attendance_Rate        0.291503          0.332866    1.004946e+00
# Project_Completed      0.658413         -0.491182    3.848806e-01
#
#                    Monthly_Salary  Performance_Score  Attendance_Rate  \
# Age                  1.425787e+04      -1.657549e+00     2.915030e-01
# Years_Experience    -2.143780e+05       1.357034e+00     3.328657e-01
# Training_Hours      -1.880102e+06       5.866220e-01     1.004946e+00
# Monthly_Salary       2.258654e+13      -1.044281e+07     1.046892e+06
# Performance_Score   -1.044281e+07       1.282775e+02    -1.269030e+00
# Attendance_Rate      1.046892e+06      -1.269030e+00     2.072012e+01
# Project_Completed   -6.740028e+05      -2.358052e-01     1.054108e-02
#
#                    Project_Completed
# Age                         0.658413
# Years_Experience           -0.491182
# Training_Hours              0.384881
# Monthly_Salary        -674002.830184
# Performance_Score          -0.235805
# Attendance_Rate             0.010541
# Project_Completed           5.310216

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

def cramers_v(x, y):
    table = pd.crosstab(x.fillna("NA"), y.fillna("NA"))
    chi2 = chi2_contingency(table)[0]
    n = table.values.sum()
    r, k = table.shape
    
    return np.sqrt(chi2 / (n * (min(r - 1, k - 1))))

def categorical_correlation_matrix(df):
    cols = df.select_dtypes(include=["object", "string"]).columns
    corr = pd.DataFrame(np.eye(len(cols)), index=cols, columns=cols)

    for i, c1 in enumerate(cols):
        for j in range(i + 1, len(cols)):
            corr.iloc[i, j] = corr.iloc[j, i] = cramers_v(df[c1], df[cols[j]])

    return corr

cat_corr = categorical_correlation_matrix(raw_df)
display(cat_corr)
# Out:
#                         Gender  Department  Education_Level  Job_Level  \
# Gender                1.000000    0.149802         0.135652   0.124890
# Department            0.149802    1.000000         0.126385   0.109417
# Education_Level       0.135652    0.126385         1.000000   0.079513
# Job_Level             0.124890    0.109417         0.079513   1.000000
# Age_Group             0.032686    0.125223         0.102727   0.100357
# Salary_Band           0.052559    0.067031         0.096124   0.121330
# Performance_Category  0.048693    0.094550         0.063035   0.110195
#
#                       Age_Group  Salary_Band  Performance_Category
# Gender                 0.032686     0.052559              0.048693
# Department             0.125223     0.067031              0.094550
# Education_Level        0.102727     0.096124              0.063035
# Job_Level              0.100357     0.121330              0.110195
# Age_Group              1.000000     0.078991              0.043162
# Salary_Band            0.078991     1.000000              0.141454
# Performance_Category   0.043162     0.141454              1.000000

# %% [markdown]
# **Your Task:** Create a Python function that can:
#
# - Compute numerical–numerical relationships using covariance
# - Compute numerical–numerical correlations using Pearson correlation
# - Compute categorical–categorical correlations using Cramér’s V
# - Produce separate matrices for covariance, numerical correlation, and categorical correlation

# %%
# === AUTO-GENERATED THUMBNAIL EXPORT ===
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import os

# Find all existing figure axes
figures = [plt.figure(i) for i in plt.get_fignums()]
if figures:
    fig = figures[-1]  # Use last figure
else:
    # Create a summary figure from available data
    fig, ax = plt.subplots(figsize=(12, 6))
    ax.text(0.5, 0.5, 'Project Visualization', fontsize=24, 
            ha='center', va='center', transform=ax.transAxes,
            fontweight='bold', color='#2d3436')
    ax.set_facecolor('#f8f9fa')
    fig.patch.set_facecolor('#f8f9fa')
    ax.axis('off')

thumbnail_path = os.path.join(os.path.dirname(os.path.abspath('__file__')), 'thumbnail.png')
fig.savefig(thumbnail_path, dpi=150, bbox_inches='tight', 
            facecolor='white', edgecolor='none')
print(f"✅ Thumbnail saved: {thumbnail_path}")
plt.show()
